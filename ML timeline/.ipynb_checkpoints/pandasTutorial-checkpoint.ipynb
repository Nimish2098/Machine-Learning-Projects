# %%
import pandas as pd

# %%
df = pd.read_csv('pokemon_data.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.tail()
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
print(df[['Type 1','Type 2']])
# Out:
#       Type 1  Type 2
# 0      Grass  Poison
# 1      Grass  Poison
# 2      Grass  Poison
# 3      Grass  Poison
# 4       Fire     NaN
# ..       ...     ...
# 795     Rock   Fairy
# 796     Rock   Fairy
# 797  Psychic   Ghost
# 798  Psychic    Dark
# 799     Fire   Water
#
# [800 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %% [markdown]
# How to Select a subset of a DataFrame ?

# %%
type1 = df['Type 1']
type1.head()
# Out:
# 0    Grass
# 1    Grass
# 2    Grass
# 3    Grass
# 4     Fire
# Name: Type 1, dtype: object

# %%
# multiple columns
t1_t2 = df[['Type 1','Type 2']]
t1_t2.head()
# Out:
#   Type 1  Type 2
# 0  Grass  Poison
# 1  Grass  Poison
# 2  Grass  Poison
# 3  Grass  Poison
# 4   Fire     NaN

# %%
above_70 = df[df['HP']>120]
above_70
# Out:
#        #                   Name    Type 1    Type 2   HP  Attack  Defense  \
# 45    40             Wigglytuff    Normal     Fairy  140      70       45
# 121  113                Chansey    Normal       NaN  250       5        5
# 142  131                 Lapras     Water       Ice  130      85       80
# 145  134               Vaporeon     Water       NaN  130      65       60
# 155  143                Snorlax    Normal       NaN  160     110       65
# 185  171                Lanturn     Water  Electric  125      58       58
# 217  202              Wobbuffet   Psychic       NaN  190      33       58
# 261  242                Blissey    Normal       NaN  255      10       10
# 313  289                Slaking    Normal       NaN  150     160      100
# 321  297               Hariyama  Fighting       NaN  144     120       60
# 350  320                Wailmer     Water       NaN  130      70       35
# 351  321                Wailord     Water       NaN  170      90       45
# ...

# %%
above_70.shape
# Out:
# (24, 12)

# %%
types = df[(df['Type 1']=='Water')&(df['Type 2']=='Ice')]

# %%
types.head()
# Out:
#        #      Name Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 94    87   Dewgong  Water    Ice   90      70       80       70       95
# 98    91  Cloyster  Water    Ice   50      95      180       85       45
# 142  131    Lapras  Water    Ice  130      85       80       85       95
#
#      Speed  Generation  Legendary
# 94      70           1      False
# 98      70           1      False
# 142     60           1      False

# %%
# lengedary_poke = df[df['Type 2'].notna()]
# legendary_poke.head()

# %%
# getting names of pokemon which have HP greater than 120
names = df.loc[df['HP']>120,'Name']
names.head(10)
# Out:
# 45     Wigglytuff
# 121       Chansey
# 142        Lapras
# 145      Vaporeon
# 155       Snorlax
# 185       Lanturn
# 217     Wobbuffet
# 261       Blissey
# 313       Slaking
# 321      Hariyama
# Name: Name, dtype: object

# %%
# specific rows and columns
df.iloc[0:10,0:4]
# Out:
#    #                       Name Type 1  Type 2
# 0  1                  Bulbasaur  Grass  Poison
# 1  2                    Ivysaur  Grass  Poison
# 2  3                   Venusaur  Grass  Poison
# 3  3      VenusaurMega Venusaur  Grass  Poison
# 4  4                 Charmander   Fire     NaN
# 5  5                 Charmeleon   Fire     NaN
# 6  6                  Charizard   Fire  Flying
# 7  6  CharizardMega Charizard X   Fire  Dragon
# 8  6  CharizardMega Charizard Y   Fire  Flying
# 9  7                   Squirtle  Water     NaN

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# creating plots in pandas
import pandas as pd
import matplotlib.pyplot as plt

# %%
stock_data = pd.read_csv('AAPL_daily_stock_data.csv')
stock_data.head()
# Out:
#          Date   Open   High    Low  Close   Volume
# 0  01-11-1999  80.00  80.69  77.37  77.62  2487300
# 1  02-11-1999  78.00  81.69  77.31  80.25  3564600
# 2  03-11-1999  81.62  83.25  81.00  81.50  2932700
# 3  04-11-1999  82.06  85.37  80.62  83.62  3384700
# 4  05-11-1999  84.62  88.37  84.00  88.31  3721500

# %%
stock_data.plot()
plt.show()

# %%
stock_data['Open'].plot()
plt.show()

# %%
stock_data.plot.scatter(x='Open',y='Volume',alpha =0.5)
# Out:
# <Axes: xlabel='Open', ylabel='Volume'>

# %%
stock_data.plot.box()
# Out:
# <Axes: >

# %%
import pandas as pd

# %%
df = pd.read_csv('AAPL_daily_stock_data.csv')
df.head()
# Out:
#          Date   Open   High    Low  Close   Volume
# 0  01-11-1999  80.00  80.69  77.37  77.62  2487300
# 1  02-11-1999  78.00  81.69  77.31  80.25  3564600
# 2  03-11-1999  81.62  83.25  81.00  81.50  2932700
# 3  04-11-1999  82.06  85.37  80.62  83.62  3384700
# 4  05-11-1999  84.62  88.37  84.00  88.31  3721500

# %%
df['Volume_in_1000s'] = df['Volume'] * .0001
df.head()
# Out:
#          Date   Open   High    Low  Close   Volume  Volume_in_1000s
# 0  01-11-1999  80.00  80.69  77.37  77.62  2487300           248.73
# 1  02-11-1999  78.00  81.69  77.31  80.25  3564600           356.46
# 2  03-11-1999  81.62  83.25  81.00  81.50  2932700           293.27
# 3  04-11-1999  82.06  85.37  80.62  83.62  3384700           338.47
# 4  05-11-1999  84.62  88.37  84.00  88.31  3721500           372.15

# %%
df['Gain/Loss'] = df['Close'] - df['Open']
df.head()
# Out:
#          Date   Open   High    Low  Close   Volume  Volume_in_1000s  Gain/Loss
# 0  01-11-1999  80.00  80.69  77.37  77.62  2487300           248.73      -2.38
# 1  02-11-1999  78.00  81.69  77.31  80.25  3564600           356.46       2.25
# 2  03-11-1999  81.62  83.25  81.00  81.50  2932700           293.27      -0.12
# 3  04-11-1999  82.06  85.37  80.62  83.62  3384700           338.47       1.56
# 4  05-11-1999  84.62  88.37  84.00  88.31  3721500           372.15       3.69

# %%
df_renamed = df.rename(
    columns = {
        'Open': 'Open',
        'Close':'Close'
    }
)
df_renamed.head()
# Out:
#          Date   Open   High    Low  Close   Volume  Volume_in_1000s  Gain/Loss
# 0  01-11-1999  80.00  80.69  77.37  77.62  2487300           248.73      -2.38
# 1  02-11-1999  78.00  81.69  77.31  80.25  3564600           356.46       2.25
# 2  03-11-1999  81.62  83.25  81.00  81.50  2932700           293.27      -0.12
# 3  04-11-1999  82.06  85.37  80.62  83.62  3384700           338.47       1.56
# 4  05-11-1999  84.62  88.37  84.00  88.31  3721500           372.15       3.69

# %%
df = pd.read_csv('pokemon_data.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# average HP of the pokemons
df['HP'].mean()
# Out:
# 69.25875

# %%
# median HP and Speed
df[['HP','Speed']].median()
# Out:
# HP       65.0
# Speed    65.0
# dtype: float64

# %%
df['HP'].describe()
# Out:
# count    800.000000
# mean      69.258750
# std       25.534669
# min        1.000000
# 25%       50.000000
# 50%       65.000000
# 75%       80.000000
# max      255.000000
# Name: HP, dtype: float64

# %%
# specific combinations of aggregating statisitcs
df.agg(
    {
        'HP':['count','mean','std'],
        'Attack':['count','mean','std']
    }
)
# Out:
#                HP      Attack
# count  800.000000  800.000000
# mean    69.258750   79.001250
# std     25.534669   32.457366

# %% [markdown]
# # Aggregating statistics grouped by category

# %%
# df['HP'].groupby('Legendary').mean()

# %%
df.groupby('Legendary').mean(numeric_only=True)
# Out:
#                     #         HP      Attack    Defense     Sp. Atk  \
# Legendary
# False      353.315646  67.182313   75.669388  71.559184   68.454422
# True       470.215385  92.738462  116.676923  99.661538  122.184615
#
#               Sp. Def       Speed  Generation
# Legendary
# False       68.892517   65.455782    3.284354
# True       105.938462  100.184615    3.769231

# %%
df.groupby('Legendary')['HP'].mean()
# Out:
# Legendary
# False    67.182313
# True     92.738462
# Name: HP, dtype: float64

# %%
# grouping can be done with more columns
df.groupby(['Legendary','Generation'])['HP'].mean()
# Out:
# Legendary  Generation
# False      1              64.612500
#            2              69.613861
#            3              64.626761
#            4              69.740741
#            5              69.353333
#            6              66.189189
# True       1              98.000000
#            2             103.400000
#            3              81.666667
#            4             100.846154
#            5              96.133333
#            6              87.500000
# Name: HP, dtype: float64

# %% [markdown]
# # Count number of records by category

# %%
df['Generation'].value_counts()
# Out:
# Generation
# 1    166
# 5    165
# 3    160
# 4    121
# 2    106
# 6     82
# Name: count, dtype: int64

# %%
# count excludes the null values 
df.groupby('Legendary')['Legendary'].count()
# Out:
# Legendary
# False    735
# True      65
# Name: Legendary, dtype: int64

# %%
# size includes all the values including null values
df.groupby('Type 1')['Type 2'].size()
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: Type 2, dtype: int64

# %%
df.groupby('Type 1')['Type 2'].count()
# Out:
# Type 1
# Bug         52
# Dark        21
# Dragon      21
# Electric    17
# Fairy        2
# Fighting     7
# Fire        24
# Flying       2
# Ghost       22
# Grass       37
# Ground      19
# Ice         11
# Normal      37
# Poison      13
# Psychic     19
# Rock        35
# Steel       22
# Water       53
# Name: Type 2, dtype: int64

# %% [markdown]
# # How to reshape the layouts of tables

# %%
# Sorting table rows
df.sort_values(by=['HP'], ascending = True).head()
# Out:
#        #      Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 316  292  Shedinja      Bug  Ghost   1      90       45       30       30
# 55    50   Diglett   Ground    NaN  10      55       25       35       45
# 139  129  Magikarp    Water    NaN  20      10       55       15       20
# 388  355   Duskull    Ghost    NaN  20      40       90       30       90
# 487  439  Mime Jr.  Psychic  Fairy  20      25       45       70       90
#
#      Speed  Generation  Legendary
# 316     40           3      False
# 55      95           1      False
# 139     80           1      False
# 388     25           3      False
# 487     60           4      False

# %%
new_df = df.sort_values(by=['HP','Attack'],ascending = True).head()

# %%
# Long to wide table format

type2 = df[df['Type 1']=='Water']
type2_sub = type2.sort_index().groupby(['Type 1']).head()
type2_sub
# Out:
#      #                     Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 9    7                 Squirtle  Water    NaN  44      48       65       50
# 10   8                Wartortle  Water    NaN  59      63       80       65
# 11   9                Blastoise  Water    NaN  79      83      100       85
# 12   9  BlastoiseMega Blastoise  Water    NaN  79     103      120      135
# 59  54                  Psyduck  Water    NaN  50      52       48       65
#
#     Sp. Def  Speed  Generation  Legendary
# 9        64     43           1      False
# 10       80     58           1      False
# 11      105     78           1      False
# 12      115     78           1      False
# 59       50     55           1      False

# %%
# generation values next to each other
gen = df.groupby(['Generation'])['Type 1'].head()
gen
# Out:
# 0        Grass
# 1        Grass
# 2        Grass
# 3        Grass
# 4         Fire
# 166      Grass
# 167      Grass
# 168      Grass
# 169       Fire
# 170       Fire
# 272      Grass
# 273      Grass
# 274      Grass
# 275      Grass
# 276       Fire
# 432      Grass
# 433      Grass
# 434      Grass
# 435       Fire
# 436       Fire
# 553    Psychic
# 554      Grass
# 555      Grass
# 556      Grass
# 557       Fire
# 718      Grass
# 719      Grass
# 720      Grass
# 721       Fire
# 722       Fire
# Name: Type 1, dtype: object
